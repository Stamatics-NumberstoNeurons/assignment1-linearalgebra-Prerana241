# %% [markdown]
# <a href="https://colab.research.google.com/github/Stamatics-NumberstoNeurons/assignment1-linearalgebra-Prerana241/blob/main/linear_algebra_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Algebra Assignment
#
# **Instructions:**
# - Read each question carefully before answering.
# - For **written/conceptual** questions, double-click the answer cell below the question and type your response.
# - For **coding** questions, write your solution in the code cell provided.
# - Run all code cells before submitting — make sure there are no errors.
# - When done, click **"Save in GitHub to keep changes"** at the top to submit.
#
# > **Tip:** Use `Shift + Enter` to run a cell and move to the next one.

# %% [markdown]
# ## Setup

# %%
# Run this cell before starting — do not modify
import numpy as np

# %% [markdown]
# ---
# ## Q2 — Matrix Transformations

# %% [markdown]
# You are given the following matrix:
#
# $$A = \begin{bmatrix} 2 & 0 \\ 0 & 3 \end{bmatrix}$$
#
# And the following vectors:
#
# ```
# v1 = [1, 0]
# v2 = [0, 1]
# v3 = [1, 1]
# v4 = [-2, 4]
# ```

# %% [markdown]
# ### Q2 Part (i) — Geometric Interpretation
#
# **Without running any code**, predict what happens when you multiply matrix `A` by each of the vectors above.
# Explain **geometrically** what the matrix is doing to each vector — not just what the numbers become.

# %% [markdown]
# *Write your answer here (double-click to edit this cell)*
# 1) When A and v1 are multiplied, the first column of A is extracted, where v1 is the horizontal basis vector.
# 2) When A and v2 are multiplied, the second column of A is extracted, where v2 is the vertical basis vector.
# 3) When A is multiplied by v3, a linear transformation takes place and a 2 x 1 vector is obtained. v3 is a linear combination of v1 and v2.
# 4) When A is multiplied by v4, a linear transformation takes place and a 2 x 1 vector is obtained. v4 is also a linear combination of v1 and v2.

# %% [markdown]
# ### Q2 Part (ii) — Respond to a Classmate
#
# A classmate says:
# > *"Matrix multiplication is just a complicated way to multiply numbers — it doesn't mean anything visually."*
#
# Using your results from Part (i), write **3–4 sentences** proving them wrong.
#
# In the linear transformations occurring due to the vector multiplications above, the origin remains fixed and straight lines remain lines - they don't curve. Matrix multiplication is used for coordinate transformations where one point is mapped to another point in space. The matrix columns show where the standard basis vectors land. The order of the matrix may change during matrix multiplication which visually changes its appearance due to rotation, reflection and shear effects.

# %% [markdown]
# ### Q2 Part (iii) — NumPy Function
#
# Write a NumPy function that:
# - Takes **any 2×2 matrix** and **any 2D vector** as inputs
# - Returns the **transformed vector**
# - Prints a **one-line description** of how the x and y components individually change
#
# Test your function on matrix `A` and all four vectors above.

# %%
# Input — do not modify
A = np.array([[2, 0], [0, 3]])
v1 = np.array([1, 0])
v2 = np.array([0, 1])
v3 = np.array([1, 1])
v4 = np.array([-2, 4])

# %%
# Write your code here:
def transform_vector(matrix, vector):
  matrix = np.array(matrix)
  vector = np.array(vector)
  transformed_vector = np.dot(matrix, vector)
  a, b = matrix[0]
  c, d = matrix[1]
  print(f"x component: {a} * {vector[0]} + {b} * {vector[1]} = {transformed_vector[0]}")
  print(f"y component: {c} * {vector[0]} + {d} * {vector[1]} = {transformed_vector[1]}")
  return transformed_vector

matrix = [[2, 0], [0, 3]]
vector = [[1, 0], [0, 1], [1, 1], [-2, 4]]
for i in vector:
  print(transform_vector(matrix, i))
# Out:
# x component: 2 * 1 + 0 * 0 = 2
# y component: 0 * 1 + 3 * 0 = 0
# [2 0]
# x component: 2 * 0 + 0 * 1 = 0
# y component: 0 * 0 + 3 * 1 = 3
# [0 3]
# x component: 2 * 1 + 0 * 1 = 2
# y component: 0 * 1 + 3 * 1 = 3
# [2 3]
# x component: 2 * -2 + 0 * 4 = -4
# y component: 0 * -2 + 3 * 4 = 12
# [-4 12]

# %% [markdown]
# ---
# ## Q3 — Tiny Recommendation System

# %% [markdown]
# Each user's taste is represented as a vector of 4 scores across 4 genres — **action, romance, thriller, comedy** — all between 0 and 1.
#
# ```
# User A: [0.9, 0.1, 0.8, 0.2]
# User B: [0.1, 0.9, 0.2, 0.8]
# User C: [0.8, 0.2, 0.9, 0.1]
# User D: [0.5, 0.5, 0.5, 0.5]
# ```

# %% [markdown]
# ### Q3 Part (i) — Similarity Matrix
#
# Compute the **full similarity matrix** — every user's similarity score against every other user — using only a **single NumPy operation** (no loops).
#
# What linear algebra concept makes this possible in one line?

# %%
# Input — do not modify
users = np.array([
    [0.9, 0.1, 0.8, 0.2],  # User A
    [0.1, 0.9, 0.2, 0.8],  # User B
    [0.8, 0.2, 0.9, 0.1],  # User C
    [0.5, 0.5, 0.5, 0.5],  # User D
])

# %%
# Write your code here:
similarity_matrix = np.dot(users, users.T)
print(similarity_matrix)
# Out:
# [[1.5  0.5  1.48 1.  ]
#  [0.5  1.5  0.52 1.  ]
#  [1.48 0.52 1.5  1.  ]
#  [1.   1.   1.   1.  ]]

# %% [markdown]
# **What linear algebra concept makes this possible in one line?**

# %% [markdown]
# *Write your answer here (double-click to edit this cell)*
#
# The concept of dot product between matrices makes this possible in one line.

# %% [markdown]
# ### Q3 Part (ii) — Reason About User D
#
# User D has **equal scores** across all genres.
#
# Before computing anything, reason through: will User D's similarity score with every other user be identical? **Why or why not?** Then verify with code.

# %% [markdown]
# *Write your answer here (double-click to edit this cell)*
#
# No it will no be identical. If D has choices all 0.5 and another user u has choices s1, s2, s3 and s4, then their similarity score is D.u which is 0.5(s1 + s2 + s3 + s4) so the score depends on the sum of the other user's choices and will not be same for all users.

# %%
# Write your code here:
import numpy as np
A = [0.9, 0.1, 0.8, 0.2]
B = [1, 9, 2, 8]
score_D_A = np.dot(A, D)
score_D_B = np.dot(B, D)
print("D.A:", score_D_A)
print("D.B:", score_D_B)
# Out:
# D.A: 1.0
# D.B: 10.0

# %% [markdown]
# ### Q3 Part (iii) — The Problem with Raw Dot Products
#
# A senior engineer tells you:
# > *"Raw dot products are a bad measure of similarity — you need to normalize."\*
#
# 1. What is the **problem** with raw dot products?
# 2. Construct a **specific example using NumPy** that demonstrates the flaw.
# 3. Fix it.
#
# > **Hint:** Take a user with scores `[1.8, 0.2, 1.6, 0.4]`

# %% [markdown]
# *Write your answer here (double-click to edit this cell)*
#
# 1) Dot products consider both magnitude and direction. If one user rates highly, then he/she will have large dot products and hence large simiarity scores with others, while another user who rates lower but has the exact same pattern will have much smaller similarity scores with others. This is misleading about the actual similarity that the users have between their choices.
#
# 2) If one user A has choices [0.9, 0.1, 0.8, 0.2] and another E has [1.8, 0.2, 1.6, 0.4], then A has a similarity acore of 1 with D and E has 2, which implies that D is more similar to E though both A and E have identical patterns, only different choice values.
#
# 3) To fix this, normalise the scores first, then compute dot product. This ensures that similar tastes have similarity scores of 1 regardless of choice values.

# %%
# Write your code here:
import numpy as np
A = [0.9, 0.1, 0.8, 0.2]
E = [1.8, 0.2, 1.6, 0.4]
sim_A_D = np.dot(A, D)
sim_E_D = np.dot(E, D)
print("D.A:", sim_A_D)
print("D.E:", sim_E_D)

sim_A_D_norm = sim_A_D / (np.linalg.norm(A) * np.linalg.norm(D))
sim_E_D_norm = sim_E_D / (np.linalg.norm(E) * np.linalg.norm(D))
print("D.A normalised:", sim_A_D_norm)
print("D.E normalised:", sim_E_D_norm)
# Out:
# D.A: 1.0
# D.E: 2.0
# D.A normalised: 0.8164965809277259
# D.E normalised: 0.8164965809277259

# %% [markdown]
# ### Q3 Part (iv) — Most Similar Users
#
# After normalizing, which **two users are most similar**?
#
# Does that match your intuition from just reading the vectors?
#
# What does it mean in plain language — what do these two users have in common?
#
# > **Note:** A similarity score is just a number that tells you **how alike two things are**.

# %% [markdown]
# *Write your answer here (double-click to edit this cell)*
#
# From intuition, by looking at the given choices, we see A and C have very close tastes. So A and C should have the highest similarity score. This means users A and C have similar inclination towards the 4 genres.

# %%
# Write your code here:
import numpy as np
A = [0.9, 0.1, 0.8, 0.2]
B = [0.1, 0.9, 0.2, 0.8]
C = [0.8, 0.2, 0.9, 0.1]
D = [0.5, 0.5, 0.5, 0.5]

names = ["A", "B", "C", "D"]
normalized = users / np.linalg.norm(users, axis = 1, keepdims = True)
cos_sim = np.dot(normalized, normalized.T)
np.fill_diagonal(cos_sim, 0)
idx = np.unravel_index(np.argmax(cos_sim), cos_sim.shape)
print(f"Most similar users are {names[idx[0]]} and {names[idx[1]]}")
# Out:
# Most similar users are A and C

# %% [markdown]
# ---
#
# ## 🎉 Submission Complete!
#
# Make sure all code cells are run and all written answers are filled in, then click **"Save in GitHub to keep changes"** at the top.
